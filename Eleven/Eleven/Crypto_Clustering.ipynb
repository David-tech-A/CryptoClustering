# %%
# Import required libraries and dependencies
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load the data into a Pandas DataFrame and make the index the "coin_id" column.
market_data_df = pd.read_csv("Resources/crypto_market_data.csv", index_col="coin_id")

# Display sample data
market_data_df.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
market_data_df.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
scaler = StandardScaler()
scaled_data = scaler.fit_transform(market_data_df)

# %%
# Create a DataFrame with the scaled data
scaled_market_data_df = pd.DataFrame(scaled_data, columns=market_data_df.columns, index=market_data_df.index)

# Display sample data
scaled_market_data_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values to try
# Use a range from 1 to 11
k_values = range(1, 11)

# Create an empty list to store the inertia values
inertia_values = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using the scaled DataFrame
# 3. Append the model.inertia_ to the inertia list
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(scaled_market_data_df)
    inertia_values.append(kmeans.inertia_)

# Create a dictionary with the data to plot the Elbow curve
elbow_data = {"k": k_values, "inertia": inertia_values}

# Create a DataFrame with the data to plot the Elbow curve
elbow_df = pd.DataFrame(elbow_data)

# Display the DataFrame
elbow_df
# Out:
#     k     inertia
# 0   1  287.000000
# 1   2  198.571818
# 2   3  145.635748
# 3   4   79.022435
# 4   5   66.217780
# 5   6   59.139070
# 6   7   48.406314
# 7   8   38.993588
# 8   9   34.400595
# 9  10   28.573603

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.

import matplotlib.pyplot as plt

plt.plot(elbow_df["k"], elbow_df["inertia"], marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Curve to Determine Optimal k')
plt.show()

# %% [markdown]
# #### Answer the following question:
# **Question:** What is the best value for `k`?
#
# **Answer:**   Based on the elbow curve, I choose the 3 k value because is where the inertia starts to decrease at a slower rate.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled Data.

# %%
# Initialize the K-Means model using the best value for k
kmeans = KMeans(n_clusters=3, random_state=0)  # Replace 3 with the best k value based on the Elbow Curve

# %%
# Fit the K-Means model using the scaled data
kmeans.fit(scaled_market_data_df)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
crypto_clusters = kmeans.predict(scaled_market_data_df)

# View the resulting array of cluster values.
crypto_clusters
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 0, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 1, 0, 0, 0, 2, 0, 0, 0, 0],
#       dtype=int32)

# %%
# Create a copy of the DataFrame
market_data_clusters_df = scaled_market_data_df.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
market_data_clusters_df["cluster"] = crypto_clusters

# Display sample data
market_data_clusters_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using Pandas plot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Use "rainbow" for the color to better visualize the data.

market_data_clusters_df.plot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    c="cluster",
    colormap="rainbow",
    colorbar=True,
    title="Cryptocurrency Clustering by Price Change (24h vs 7d)"
)
# Out:
# <Axes: title={'center': 'Cryptocurrency Clustering by Price Change (24h vs 7d)'}, xlabel='price_change_percentage_24h', ylabel='price_change_percentage_7d'>

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` on the original scaled DataFrame to reduce to three principal components.
pca_data = pca.fit_transform(scaled_market_data_df) 
# View the first five rows of the DataFrame. 
pca_data[:5]
# Out:
# array([[-0.60066733,  0.84276006,  0.46159457],
#        [-0.45826071,  0.45846566,  0.95287678],
#        [-0.43306981, -0.16812638, -0.64175193],
#        [-0.47183495, -0.22266008, -0.47905316],
#        [-1.15779997,  2.04120919,  1.85971527]])

# %%
# Retrieve the explained variance to determine how much information  can be attributed to each principal component.
explained_variance = pca.explained_variance_ratio_

# Display the explained variance
explained_variance
# Out:
# array([0.3719856 , 0.34700813, 0.17603793])

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:**   The total of the three principal components generated by PCA is:
#
# PCA1: 0.3719856
# PCA2: 0.34700813
# PCA3: 0.17603793
#
# total_explained_variance≈0.89503166
#
# This value indicates that the three principal components explain approximately 89.5% of the total variability in the data.

# %%
# Create a new DataFrame with the PCA data.
# Note: The code for this step is provided for you




# Creating a DataFrame with the PCA data


# Copy the crypto names from the original data


# Set the coinid column as index


# Display sample data
pca_market_data_df = pd.DataFrame(pca_data, columns=["PCA1", "PCA2", "PCA3"], index=market_data_df.index)
pca_market_data_df.head()
# Out:
#                   PCA1      PCA2      PCA3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values to try
# Use a range from 1 to 11

k_values_pca = range(1, 11) 
# Create an empty list to store the inertia values

inertia_values_pca = [] 
# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using PCA DataFrame.
# 3. Append the model.inertia_ to the inertia list
for k in k_values_pca:
    kmeans_pca = KMeans(n_clusters=k, random_state=0)
    kmeans_pca.fit(pca_market_data_df)
    inertia_values_pca.append(kmeans_pca.inertia_)

# Create a dictionary with the data to plot the Elbow curve


# Create a DataFrame with the data to plot the Elbow curve
elbow_data_pca = {"k": k_values_pca, "inertia": inertia_values_pca}
elbow_df_pca = pd.DataFrame(elbow_data_pca) 

# Display the DataFrame
elbow_df_pca
# Out:
#     k     inertia
# 0   1  256.874086
# 1   2  168.811896
# 2   3  115.918077
# 3   4   49.665497
# 4   5   41.357314
# 5   6   30.796642
# 6   7   25.915457
# 7   8   21.890936
# 8   9   17.720699
# 9  10   13.838699

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
plt.plot(elbow_df_pca["k"], elbow_df_pca["inertia"], marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Curve to Determine Optimal k (PCA Data)')
plt.show()

# %% [markdown]
# #### Answer the following questions:
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:**
# The best value for k when using the PCA data is 4, as indicated by the elbow point in the inertia values
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:**
#
#
#   Yes, it does differ. The best value for k using the original data was 5, indicating that dimensionality reduction with PCA can impact the optimal number of clusters.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
kmeans_pca = KMeans(n_clusters=4, random_state=0)

# %%
# Fit the K-Means model using the PCA data
kmeans_pca.fit(pca_market_data_df)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
crypto_clusters_pca = kmeans_pca.predict(pca_market_data_df)

# Print the resulting array of cluster values.
crypto_clusters_pca
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 1, 2, 0, 0, 3, 0, 0, 0, 0],
#       dtype=int32)

# %%
# Create a copy of the DataFrame with the PCA data
pca_market_data_clusters_df = pca_market_data_df.copy()


# Add a new column to the DataFrame with the predicted clusters
pca_market_data_clusters_df["crypto_cluster"] = crypto_clusters_pca


# Display sample data
pca_market_data_clusters_df.head()
# Out:
#                   PCA1      PCA2      PCA3  crypto_cluster
# coin_id
# bitcoin      -0.600667  0.842760  0.461595               2
# ethereum     -0.458261  0.458466  0.952877               2
# tether       -0.433070 -0.168126 -0.641752               0
# ripple       -0.471835 -0.222660 -0.479053               0
# bitcoin-cash -1.157800  2.041209  1.859715               2

# %%
# Create a scatter plot using hvPlot by setting `x="PCA1"` and `y="PCA2"`. 
# Color by "crypto_cluster" to visualize clusters.

pca_market_data_clusters_df.plot.scatter(
    x="PCA1",
    y="PCA2",
    c="crypto_cluster",
    colormap="viridis",
    colorbar=True,
    title="Clusters of Cryptocurrencies (PCA1 vs PCA2)"
)
# Out:
# <Axes: title={'center': 'Clusters of Cryptocurrencies (PCA1 vs PCA2)'}, xlabel='PCA1', ylabel='PCA2'>

# %% [markdown]
# ### Determine the Weights of Each Feature on each Principal Component

# %%
# Use the columns from the original scaled DataFrame as the index
pca_components = pd.DataFrame(pca.components_, columns=market_data_df.columns, index=["PCA1", "PCA2", "PCA3"])

# Display the weights of each feature on each principal component
pca_components
# Out:
#       price_change_percentage_24h  price_change_percentage_7d  \
# PCA1                    -0.416728                   -0.102432
# PCA2                     0.358162                    0.227432
# PCA3                    -0.218795                    0.787670
#
#       price_change_percentage_14d  price_change_percentage_30d  \
# PCA1                    -0.009162                     0.191523
# PCA2                     0.540415                     0.562182
# PCA3                     0.349534                    -0.181744
#
#       price_change_percentage_60d  price_change_percentage_200d  \
# PCA1                     0.320365                      0.594468
# PCA2                     0.434040                      0.027735
# PCA3                    -0.361377                      0.039733
#
#       price_change_percentage_1y
# PCA1                    0.568379
# PCA2                   -0.150789
# PCA3                    0.210541

# %% [markdown]
# #### Answer the following question:
#
# * **Question:** Which features have the strongest positive or negative influence on each component?
#
# * **Answer:**
#
#
# PCA1: The features with the strongest influence are:
# Strong Positive Influence: price_change_percentage_200d (0.594468) and price_change_percentage_1y (0.568379).
# Strong Negative Influence: price_change_percentage_24h (-0.416728).
#
# PCA2: The features with the strongest influence are:
# Strong Positive Influence: price_change_percentage_30d (0.562182) and price_change_percentage_14d (0.540415).
# Strong Negative Influence: price_change_percentage_1y (-0.150789).
#
# PCA3: The features with the strongest influence are:
# Strong Positive Influence: price_change_percentage_7d (0.787670) and price_change_percentage_14d (0.349534).
# Strong Negative Influence: price_change_percentage_60d (-0.361377).
